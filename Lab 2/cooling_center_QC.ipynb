# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import shapely.geometry
import psycopg2
from sqlalchemy import create_engine
import geoalchemy2
import requests
import zipfile

# %%
#database connection parameters
db_params = {
    "host": "34.30.71.239",
    "port": "5432",
    "dbname": "gis_data",
    "user": "",
    "password": ""
}

#db connection string
db_string = f'postgresql+psycopg2://{db_params["user"]}:{db_params["password"]}@{db_params["host"]}:{db_params["port"]}/{db_params["dbname"]}'
engine = create_engine(db_string)

# %%
#define cooling center table variable and load

cooling_options = "cooling_options"
cooling_options_df = pd.read_sql(f"SELECT * FROM {cooling_options}", engine)

# %%
#visualize table
print(cooling_options_df)
# Out:
#       id                                           geometry  \
# 0      1  010100002023690000D03B4ED151651B4152499D9CCA06...
# 1      2  010100002023690000F0E461E1F6661B412041F18B9A06...
# 2      3  010100002023690000D0E53F64C4221B41A067B31610FC...
# 3      4  0101000020236900003080B780EE371B410EE02DC854FC...
# 4      5  010100002023690000D076BEDF375F1B41E09C11C506FD...
# ..   ...                                                ...
# 313  314  010100002023690000E03FA41F58D21C415A643BBF1302...
# 314  315  01010000202369000080C954011DCA1C419EEFA7861303...
# 315  316  010100002023690000E0240681FBB91C41EE7C3F9DC2FA...
# 316  317  010100002023690000D07F48BFB2B31C416ABC74BB1A0C...
# 317  318  010100002023690000D012F24126151D417C3F35FE91FC...
#
#                                                 name                address  \
# 0                                    Camp Ihduhapi 1    3425 Ihduhapi Trail
# 1                                    Camp Ihduhapi 2    3425 Ihduhapi Trail
# 2                                      Camp Voyageur      7000 County Rd 15
# 3                            Day Camp Christmas Tree    6365 Game Farm Rd E
# 4                                       Canary Beach        1550 Canary Ln.
# ..                                               ...                    ...
# 313  Lunds & Byerly's Golden Valley (Caribou Coffee)         5725 Duluth St
# 314                               Target (Starbucks)        7535 W Broadway
# 315                         Municipal Service Center         7305 Oxford St
# 316               Crystal Cafe & Grill (Coffee Shop)      2732 Douglas Dr N
# 317                                     Seven Points  3001 Hennepin Ave. S.
#
#                city    zip           phone           type  status  \
# 0           Loretto  55357    612-822-2267     Camp Beach  Active
# 1           Loretto  55357    612-822-2267     Camp Beach  Active
# 2             Mound  55364    612-817-2185     Camp Beach  Active
# 3             Mound  55364    952-472-1018     Camp Beach  Active
# 4             Mound  55364            None       HC Beach  Active
# ..              ...    ...             ...            ...     ...
# 313   Golden Valley  55422  (763) 544-8846      Misc Site  Active
# 314   Brooklyn Park  55428  (763) 425-5400      Misc Site  Active
# 315  St. Louis Park  55426  (952) 924-2562      Govt Bldg  Active
# 316     Minneapolis  55422  (763) 595-0655      Misc Site  Active
# 317     Minneapolis  55408            None  Shopping Mall  Remove
#
#                   hours  ...   in_out notes joinfield        utm_x  \
# 0                  None  ...  Outdoor  None         0  448852.4544
# 1                  None  ...  Outdoor  None         0  448957.7201
# 2                  None  ...  Outdoor  None         0  444593.0979
# 3                  None  ...  Outdoor  None         0  445947.6257
# 4                  None  ...  Outdoor  None         0  448461.9685
# ..                  ...  ...      ...   ...       ...          ...
# 313    Mon-Sun 6am-10pm  ...   Indoor  None         0  472214.0309
# 314    Mon-Sun 8am-10pm  ...   Indoor  None         0  471687.2513
# 315  Mon-Sun 7am-3:30pm  ...   Indoor  None         0  470654.8760
# 316     Mon-Sun 7am-2pm  ...   Indoor  None         0  470252.6868
# 317                None  ...   Indoor  None         0  476489.5644
#
#             utm_y   latitude  longitude  climateana   censustrac  inhennepin
# 0    4.987690e+06  45.040823 -93.649416   28.420902  27053027002    Hennepin
# 1    4.987498e+06  45.039100 -93.648060   28.420902  27053027002    Hennepin
# 2    4.976704e+06  44.941614 -93.702284   11.465597  27053027701    Hennepin
# 3    4.976979e+06  44.944192 -93.685146   11.465597  27053027701    Hennepin
# 4    4.977691e+06  44.950787 -93.653350   30.699513  27053027601    Hennepin
# ..            ...        ...        ...         ...          ...         ...
# 313  4.982863e+06   0.000000   0.000000   49.851378  27053021602    Hennepin
# 314  4.983886e+06   0.000000   0.000000   48.827409  27053021002    Hennepin
# 315  4.975370e+06   0.000000   0.000000   33.583468  27053023000    Hennepin
# 316  4.993131e+06   0.000000   0.000000   57.084732  27053026818    Hennepin
# 317  4.977224e+06   0.000000   0.000000   55.469888  27053008100    Hennepin
#
# [318 rows x 22 columns]

# %%
#view specifically 'fee' and 'inhennepin' fields
print(cooling_options_df[['fee','inhennepin']])
# Out:
#      fee inhennepin
# 0    Yes   Hennepin
# 1    Yes   Hennepin
# 2    Yes   Hennepin
# 3    Yes   Hennepin
# 4     No   Hennepin
# ..   ...        ...
# 313   No   Hennepin
# 314   No   Hennepin
# 315   No   Hennepin
# 316  Yes   Hennepin
# 317   No   Hennepin
#
# [318 rows x 2 columns]

# %%
#remove any cooling center where fee attribute = yes and inhennepin = no
cooling_options_df_filtered = cooling_options_df[(cooling_options_df["inhennepin"] != "No") & (cooling_options_df["fee"] != "Yes")]

# %%
#visualize filtered table
print(cooling_options_df_filtered)
# Out:
#       id                                           geometry  \
# 4      5  010100002023690000D076BEDF375F1B41E09C11C506FD...
# 5      6  010100002023690000806132D560891B41A2B4377C41FA...
# 6      7  010100002023690000E02D90A0E05A1B41984C150CD0F9...
# 7      8  010100002023690000C07493D84EE11B41A679C7CD21FA...
# 8      9  010100002023690000E08C28ADE79A1B41CEAACFCD80FA...
# ..   ...                                                ...
# 312  313  010100002023690000B0A44EC0BF4C1D4188D2DE8C90FC...
# 313  314  010100002023690000E03FA41F58D21C415A643BBF1302...
# 314  315  01010000202369000080C954011DCA1C419EEFA7861303...
# 315  316  010100002023690000E0240681FBB91C41EE7C3F9DC2FA...
# 317  318  010100002023690000D012F24126151D417C3F35FE91FC...
#
#                                                 name                address  \
# 4                                       Canary Beach        1550 Canary Ln.
# 5                                  Casco Point Beach  2879 Casco Point Road
# 6                                      Chester Beach       5186 Tuxedo Blvd
# 7                                      Linwood Beach     20700 Linwood Road
# 8                                      Lydiard Beach         Lydiard Avenue
# ..                                               ...                    ...
# 312                                  Mercado Central       1515 E. Lake St.
# 313  Lunds & Byerly's Golden Valley (Caribou Coffee)         5725 Duluth St
# 314                               Target (Starbucks)        7535 W Broadway
# 315                         Municipal Service Center         7305 Oxford St
# 317                                     Seven Points  3001 Hennepin Ave. S.
#
#                city    zip           phone           type  status  \
# 4             Mound  55364            None       HC Beach  Active
# 5           Wayzata  55391            None       HC Beach  Active
# 6             Mound  55364            None       HC Beach  Active
# 7         Excelsior  55331            None       HC Beach  Active
# 8         Excelsior  55331            None       HC Beach  Active
# ..              ...    ...             ...            ...     ...
# 312     Minneapolis  55407    612-728-5485  Shopping Mall  Active
# 313   Golden Valley  55422  (763) 544-8846      Misc Site  Active
# 314   Brooklyn Park  55428  (763) 425-5400      Misc Site  Active
# 315  St. Louis Park  55426  (952) 924-2562      Govt Bldg  Active
# 317     Minneapolis  55408            None  Shopping Mall  Remove
#
#                    hours  ...   in_out                                 notes  \
# 4                   None  ...  Outdoor                                  None
# 5                   None  ...  Outdoor                                  None
# 6                   None  ...  Outdoor                                  None
# 7                   None  ...  Outdoor                                  None
# 8                   None  ...  Outdoor                                  None
# ..                   ...  ...      ...                                   ...
# 312  Open daily 10am-8pm  ...   Indoor  Indoor shopping, food, and services.
# 313     Mon-Sun 6am-10pm  ...   Indoor                                  None
# 314     Mon-Sun 8am-10pm  ...   Indoor                                  None
# 315   Mon-Sun 7am-3:30pm  ...   Indoor                                  None
# 317                 None  ...   Indoor                                  None
#
#     joinfield        utm_x         utm_y   latitude  longitude  climateana  \
# 4           0  448461.9685  4.977691e+06  44.950787 -93.653350   30.699513
# 5           0  451160.2082  4.974854e+06  44.925439 -93.618872   38.110868
# 6           0  448184.1568  4.974400e+06  44.921144 -93.656534   22.223379
# 7           0  456787.7115  4.974727e+06  44.924662 -93.547556   11.712170
# 8           0  452281.9191  4.975107e+06  44.927795 -93.604683   38.110868
# ..        ...          ...           ...        ...        ...         ...
# 312         0  480047.9378  4.977218e+06  44.948119 -93.252921   61.546919
# 313         0  472214.0309  4.982863e+06   0.000000   0.000000   49.851378
# 314         0  471687.2513  4.983886e+06   0.000000   0.000000   48.827409
# 315         0  470654.8760  4.975370e+06   0.000000   0.000000   33.583468
# 317         0  476489.5644  4.977224e+06   0.000000   0.000000   55.469888
#
#       censustrac  inhennepin
# 4    27053027601    Hennepin
# 5    27053027203    Hennepin
# 6    27053027602    Hennepin
# 7    27053027400    Hennepin
# 8    27053027203    Hennepin
# ..           ...         ...
# 312  27053008500    Hennepin
# 313  27053021602    Hennepin
# 314  27053021002    Hennepin
# 315  27053023000    Hennepin
# 317  27053008100    Hennepin
#
# [250 rows x 22 columns]

# %%
#double check filtered columns
print(cooling_options_df_filtered[['fee','inhennepin']])
# Out:
#     fee inhennepin
# 4    No   Hennepin
# 5    No   Hennepin
# 6    No   Hennepin
# 7    No   Hennepin
# 8    No   Hennepin
# ..   ..        ...
# 312  No   Hennepin
# 313  No   Hennepin
# 314  No   Hennepin
# 315  No   Hennepin
# 317  No   Hennepin
#
# [250 rows x 2 columns]

# %%
#make the cooling options dataframe a geodataframe with geopandas
cooling_options_gdf = gpd.GeoDataFrame(cooling_options_df_filtered, geometry=gpd.points_from_xy(cooling_options_df_filtered["longitude"], cooling_options_df_filtered["latitude"]))

# %%
#double check by verifying all cooling center points are with hennepin county polygon

#download mn counties shapefile
url = "https://resources.gisdata.mn.gov/pub/gdrs/data/pub/us_mn_state_dnr/bdry_counties_in_minnesota/shp_bdry_counties_in_minnesota.zip"
response = requests.get(url)
with open("mn_county.zip", "wb") as f:
    f.write(response.content)

# Extract the GeoPackage file
with zipfile.ZipFile("mn_county.zip", "r") as zip_ref:
    zip_ref.extractall("mn_county")

# %%
#load the downloaded shapefile with geopandas and print to view
mn_county_path = "C:\Users\KOlso\OneDrive\Documents\ArcGIS\Projects\GIS5571_Lab2\mn_county\mn_county_boundaries_500.shp"
mn_county = gpd.read_file(mn_county_path)

#only need county name
print(mn_county['CTY_NAME'])
# Out:
# 0      Lake of the Woods
# 1                Kittson
# 2                 Roseau
# 3            Koochiching
# 4               Marshall
#              ...
# 112                 Cook
# 113                 Cook
# 114                 Cook
# 115                 Lake
# 116                 Lake
# Name: CTY_NAME, Length: 117, dtype: object

# %%
#filter to just be hennepin county
hennepin_county = mn_county[(mn_county["CTY_NAME"] == "Hennepin")]
print(hennepin_county)
hennepin_county.explore()
# Out:
#             AREA      PERIMETER  CTYONLY_  CTYONLY_ID  COUN  CTY_NAME  \
# 49  1.570587e+09  190077.767485      51.0        50.0    27  Hennepin
#
#    CTY_ABBR  CTY_FIPS  MaxSimpTol  MinSimpTol     Shape_Leng    Shape_Area  \
# 49     HENN        53       500.0       500.0  176369.888097  1.569322e+09
#
#                                              geometry
# 49  POLYGON ((459105.693 5010507.644, 459790.33 50...
# Matplotlib is building the font cache; this may take a moment.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3fa08d8e2f4dd10651e87e9a0040f366 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3fa08d8e2f4dd10651e87e9a0040f366&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3fa08d8e2f4dd10651e87e9a0040f366 = L.map(
#                 &quot;map_3fa08d8e2f4dd10651e87e9a0040f366&quot;,
#                 {
#                     center: [45.016068987811764, -93.47291768889863],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_3fa08d8e2f4dd10651e87e9a0040f366);
#
#
#
#
#
#             var tile_layer_3ec641ed200d6f4094d595a35acee69d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ec641ed200d6f4094d595a35acee69d.addTo(map_3fa08d8e2f4dd10651e87e9a0040f366);
#
#
#             map_3fa08d8e2f4dd10651e87e9a0040f366.fitBounds(
#                 [[44.78526388073182, -93.76771466682521], [45.24687409489171, -93.17812071097204]],
#                 {}
#             );
#
#
#         function geo_json_e762a75bc9af2e2a03ed425ba4798a36_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e762a75bc9af2e2a03ed425ba4798a36_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e762a75bc9af2e2a03ed425ba4798a36_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_e762a75bc9af2e2a03ed425ba4798a36_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e762a75bc9af2e2a03ed425ba4798a36_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_e762a75bc9af2e2a03ed425ba4798a36.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e762a75bc9af2e2a03ed425ba4798a36_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e762a75bc9af2e2a03ed425ba4798a36 = L.geoJson(null, {
#                 onEachFeature: geo_json_e762a75bc9af2e2a03ed425ba4798a36_onEachFeature,
#
#                 style: geo_json_e762a75bc9af2e2a03ed425ba4798a36_styler,
#                 pointToLayer: geo_json_e762a75bc9af2e2a03ed425ba4798a36_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_e762a75bc9af2e2a03ed425ba4798a36_add (data) {
#             geo_json_e762a75bc9af2e2a03ed425ba4798a36
#                 .addData(data);
#         }
#             geo_json_e762a75bc9af2e2a03ed425ba4798a36_add({&quot;bbox&quot;: [-93.76771466682521, 44.78526388073182, -93.17812071097204, 45.24687409489171], &quot;features&quot;: [{&quot;bbox&quot;: [-93.76771466682521, 44.78526388073182, -93.17812071097204, 45.24687409489171], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-93.5211052621611, 45.24687409489171], [-93.51237365337602, 45.24604497882412], [-93.48588183610282, 45.22616352108734], [-93.42675665262577, 45.21607471134646], [-93.4119915150258, 45.19862058606419], [-93.30516508008853, 45.14151588061923], [-93.29441587097746, 45.114709769989794], [-93.2783358690691, 45.103272816174346], [-93.2832829012254, 45.035458457163706], [-93.22687551887269, 45.035638631107986], [-93.20816241026735, 45.

# %%
#to check if all cooling centers are within hennepin county, first check both df using the same CRS

#set cooling_centers_gdf CRS
cooling_options_gdf = cooling_options_gdf.set_crs(epsg=32615) #UTM 15N

hennepin_county = hennepin_county.to_crs(epsg=32615)  #UTM 15N
cooling_options = cooling_options_gdf.to_crs(hennepin_county.crs)

# %%
#run check to see if points are inside hennepin
cooling_options["inside_hennepin"] = cooling_options.geometry.within(hennepin_county.geometry.iloc[0])

inside_count = cooling_options["inside_hennepin"].sum()
total_count = len(cooling_options)

print(f"{inside_count} out of {total_count} points are within Hennepin County.")
# Out:
# 0 out of 250 points are within Hennepin County.

# %%
#replace existing cooling options table in database with the now filtered one

db_connection = "postgresql://**:**@34.30.71.239:5432/gis_data"
engine = create_engine(db_connection)

cooling_options_gdf.to_postgis(name = "cooling_options", con=engine, if_exists="replace", index = False)
